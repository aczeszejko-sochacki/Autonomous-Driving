# %% [markdown]
# # Fisheye photo transformation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage import transform, data, io
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('data/record_image.jpg')

# %%
# Define camera matrix K
K = np.array([[673.9683892, 0., 343.68638231],
              [0., 676.08466459, 245.31865398],
              [0., 0., 1.]])

# Define distortion coefficients d
d = np.array([-0.36824145, 0.2848545, 0.00079123, 0.00064924, -0.16345661])

# Read an example image and acquire its size
h, w = img.shape[:2]

# Generate new camera matrix from parameters
newcameramatrix, roi = cv2.getOptimalNewCameraMatrix(K, d, (w,h), 0)

# Generate look-up tables for remapping the camera image
mapx, mapy = cv2.initUndistortRectifyMap(K, d, None, newcameramatrix, (w, h), 5)

# Remap the original image to a new image
new_img = cv2.remap(img, mapx, mapy, cv2.INTER_LINEAR)

# %%
# Display new image
plt.imshow(newimg)

# %%
# Display old image
plt.imshow(img)
